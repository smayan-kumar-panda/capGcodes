# %% [markdown]
# <a href="https://colab.research.google.com/github/smayan-kumar-panda/capGcodes/blob/main/PandasPracticeCapG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('house_price_extreme_messy_15654_rows.csv')
data.head()
# Out:
#   House_ID   Date_Sold          City Area_sqft Bedrooms  Bathrooms Garage  \
# 0    H5239  2020/02/21  Bhubaneshwar      1503        1          4    Yes
# 1    H2788  2020-11-14  Bhubaneshwar       918        3          1     No
# 2    H5208    29/11/20  Bhubaneshwar      1358      Two          2      N
# 3    H1742  2022/03/21       Cuttack      1085    Three          4      N
# 4    H4533  2023/10/25   Bhubaneswar      3292        1          3     No
#
#    Year_Built    Price Owner_Name  ...               Email Property_Type  \
# 0        1981     5.7M      Pooja  ...     pooja#gmail.com          Flat
# 1        2014  8350753     Rakesh  ...  rakesh@outlook.com     Apartment
# 2        1995     9.8M      Meena  ...     meena@gmail.com     Apartment
# 3        2028  5679591       Arun  ...      arun@gmail.com          Flat
# 4        2028  2054447     Rajesh  ...  rajesh@outlook.com           APT
#
#   Furnished Floor_No Total_Floors  Latitude  Longitude  Loan_Status  \
# ...

# %%
data.shape
# Out:
# (15654, 21)

# %%
data.columns
# Out:
# Index(['House_ID', 'Date_Sold', 'City', 'Area_sqft', 'Bedrooms', 'Bathrooms',
#        'Garage', 'Year_Built', 'Price', 'Owner_Name', 'Contact', 'Email',
#        'Property_Type', 'Furnished', 'Floor_No', 'Total_Floors', 'Latitude',
#        'Longitude', 'Loan_Status', 'Registration_Price', 'Notes'],
#       dtype='object')

# %%
data.rename(columns={'House_ID':'HOUSEID','Owner_Name':'OwnerName'},inplace=True)
data
# Out:
#       HOUSEID   Date_Sold          City Area_sqft Bedrooms  Bathrooms Garage  \
# 0       H5239  2020/02/21  Bhubaneshwar      1503        1          4    Yes
# 1       H2788  2020-11-14  Bhubaneshwar       918        3          1     No
# 2       H5208    29/11/20  Bhubaneshwar      1358      Two          2      N
# 3       H1742  2022/03/21       Cuttack      1085    Three          4      N
# 4       H4533  2023/10/25   Bhubaneswar      3292        1          3     No
# ...       ...         ...           ...       ...      ...        ...    ...
# 15649   H2162    12/07/22          Puri      2004      Two          3    Yes
# 15650   H4306  2021-11-01  Bhubaneshwar      2950        4          4     No
# 15651   H4935  2022-04-30          Puri      2377        2          1    YES
# 15652   H1478  2020-04-02          BBSR       980        1          3      Y
# 15653   H0928  2020-06-27       Khordha      2456        2          1    YES
#
# ...

# %%
data.dtypes
# Out:
# HOUSEID                object
# Date_Sold              object
# City                   object
# Area_sqft              object
# Bedrooms               object
# Bathrooms               int64
# Garage                 object
# Year_Built              int64
# Price                  object
# OwnerName              object
# Contact                object
# Email                  object
# Property_Type          object
# Furnished              object
# Floor_No               object
# Total_Floors            int64
# Latitude              float64
# Longitude             float64
# Loan_Status            object
# Registration_Price      int64
# Notes                  object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15654 entries, 0 to 15653
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   HOUSEID             15654 non-null  object
#  1   Date_Sold           15654 non-null  object
#  2   City                15654 non-null  object
#  3   Area_sqft           15599 non-null  object
#  4   Bedrooms            15654 non-null  object
#  5   Bathrooms           15654 non-null  int64
#  6   Garage              15654 non-null  object
#  7   Year_Built          15654 non-null  int64
#  8   Price               15578 non-null  object
#  9   OwnerName           15654 non-null  object
#  10  Contact             15654 non-null  object
#  11  Email               15654 non-null  object
#  12  Property_Type       15654 non-null  object
#  13  Furnished           15654 non-null  object
#  14  Floor_No            15654 non-null  object
# ...

# %%
data.describe()
# Out:
#           Bathrooms    Year_Built  Total_Floors      Latitude     Longitude  \
# count  15654.000000  15654.000000  15654.000000  15654.000000  15654.000000
# mean       2.490290   2015.409799      8.021656     20.001870     85.997432
# std        1.120596     15.799449      4.308147      0.288759      0.288138
# min        1.000000   1980.000000      1.000000     19.500100     85.500200
# 25%        1.000000   2003.000000      4.000000     19.755000     85.749500
# 50%        2.000000   2028.000000      8.000000     20.002050     85.997400
# 75%        3.000000   2028.000000     12.000000     20.253275     86.246500
# max        4.000000   2028.000000     15.000000     20.500000     86.500000
#
#        Registration_Price
# count        1.565400e+04
# mean         8.534412e+06
# std          3.742937e+06
# min          2.000402e+06
# 25%          5.295635e+06
# 50%          8.568411e+06
# 75%          1.181919e+07
# max          1.499864e+07

# %%
data.describe(include='object')
# Out:
#        HOUSEID Date_Sold         City     Area_sqft Bedrooms Garage  Price  \
# count    15654     15654        15654         15599    15654  15654  15578
# unique    6782      5560            6          5243        6      5  11762
# top      H4757  06/02/25  Bhubaneswar  One Thousand    Three      Y   6.0M
# freq         9        12         2686            25     2678   3191     41
#
#        OwnerName     Contact       Email Property_Type Furnished Floor_No  \
# count      15654       15654       15654         15654     15654    15654
# unique         9        5322          45             5         4        6
# top         Amit  0000000000  amit@gmail         House       Yes        3
# freq        1824        5231         634          3252      3981     2636
#
#        Loan_Status          Notes
# count        15654           9360
# unique           3              3
# top       Rejected  Good property
# freq          5226           3164

# %%
data.isnull().sum()
# Out:
# HOUSEID                  0
# Date_Sold                0
# City                     0
# Area_sqft               55
# Bedrooms                 0
# Bathrooms                0
# Garage                   0
# Year_Built               0
# Price                   76
# OwnerName                0
# Contact                  0
# Email                    0
# Property_Type            0
# Furnished                0
# Floor_No                 0
# Total_Floors             0
# Latitude                 0
# Longitude                0
# Loan_Status              0
# Registration_Price       0
# Notes                 6294
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data['Notes'].isnull().sum()
# Out:
# np.int64(6294)

# %%
((data['Notes'].isnull().sum()) / len(data['Notes'])) * 100
# Out:
# np.float64(40.20697585281717)

# %%
data
# Out:
#       HOUSEID   Date_Sold          City Area_sqft Bedrooms  Bathrooms Garage  \
# 0       H5239  2020/02/21  Bhubaneshwar      1503        1          4    Yes
# 1       H2788  2020-11-14  Bhubaneshwar       918        3          1     No
# 2       H5208    29/11/20  Bhubaneshwar      1358      Two          2      N
# 3       H1742  2022/03/21       Cuttack      1085    Three          4      N
# 4       H4533  2023/10/25   Bhubaneswar      3292        1          3     No
# ...       ...         ...           ...       ...      ...        ...    ...
# 15649   H2162    12/07/22          Puri      2004      Two          3    Yes
# 15650   H4306  2021-11-01  Bhubaneshwar      2950        4          4     No
# 15651   H4935  2022-04-30          Puri      2377        2          1    YES
# 15652   H1478  2020-04-02          BBSR       980        1          3      Y
# 15653   H0928  2020-06-27       Khordha      2456        2          1    YES
#
# ...

# %%
data['Date_Sold']=pd.to_datetime(data['Date_Sold'],format='string',errors='coerce')   # converts to datetime format
data
# Out:
#       HOUSEID Date_Sold          City Area_sqft Bedrooms  Bathrooms Garage  \
# 0       H5239       NaT  Bhubaneshwar      1503        1          4    Yes
# 1       H2788       NaT  Bhubaneshwar       918        3          1     No
# 2       H5208       NaT  Bhubaneshwar      1358      Two          2      N
# 3       H1742       NaT       Cuttack      1085    Three          4      N
# 4       H4533       NaT   Bhubaneswar      3292        1          3     No
# ...       ...       ...           ...       ...      ...        ...    ...
# 15649   H2162       NaT          Puri      2004      Two          3    Yes
# 15650   H4306       NaT  Bhubaneshwar      2950        4          4     No
# 15651   H4935       NaT          Puri      2377        2          1    YES
# 15652   H1478       NaT          BBSR       980        1          3      Y
# 15653   H0928       NaT       Khordha      2456        2          1    YES
#
# ...

# %%
data['Date_Sold'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 15654 entries, 0 to 15653
# Series name: Date_Sold
# Non-Null Count  Dtype
# --------------  -----
# 0 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 122.4 KB

# %%
data['Day']=data['Date_Sold'].dt.day
data['Month']=data['Date_Sold'].dt.month
data['Year']=data['Date_Sold'].dt.year

# %%
data
# Out:
#       HOUSEID Date_Sold          City Area_sqft Bedrooms  Bathrooms Garage  \
# 0       H5239       NaT  Bhubaneshwar      1503        1          4    Yes
# 1       H2788       NaT  Bhubaneshwar       918        3          1     No
# 2       H5208       NaT  Bhubaneshwar      1358      Two          2      N
# 3       H1742       NaT       Cuttack      1085    Three          4      N
# 4       H4533       NaT   Bhubaneswar      3292        1          3     No
# ...       ...       ...           ...       ...      ...        ...    ...
# 15649   H2162       NaT          Puri      2004      Two          3    Yes
# 15650   H4306       NaT  Bhubaneshwar      2950        4          4     No
# 15651   H4935       NaT          Puri      2377        2          1    YES
# 15652   H1478       NaT          BBSR       980        1          3      Y
# 15653   H0928       NaT       Khordha      2456        2          1    YES
#
# ...

# %%
data['Area_sqft'].unique()
# Out:
# array(['1503', '918', '1358', ..., '2928 sqft', '609', '1815 sqft'],
#       dtype=object)

# %%
data['Area_sqft']=data['Area_sqft'].str.extract(r'(\d+)')

# %%
data.head()
# Out:
#   HOUSEID Date_Sold          City Area_sqft Bedrooms  Bathrooms Garage  \
# 0   H5239       NaT  Bhubaneshwar      1503        1          4    Yes
# 1   H2788       NaT  Bhubaneshwar       918        3          1     No
# 2   H5208       NaT  Bhubaneshwar      1358      Two          2      N
# 3   H1742       NaT       Cuttack      1085    Three          4      N
# 4   H4533       NaT   Bhubaneswar      3292        1          3     No
#
#    Year_Built    Price OwnerName  ... Floor_No Total_Floors Latitude  \
# 0        1981     5.7M     Pooja  ...   Ground            5  20.3094
# 1        2014  8350753    Rakesh  ...        2            2  20.3553
# 2        1995     9.8M     Meena  ...        3            5  19.5662
# 3        2028  5679591      Arun  ...   Ground            2  19.8848
# 4        2028  2054447    Rajesh  ...        1            6  20.2625
#
#   Longitude Loan_Status  Registration_Price             Notes  Day Month  Year
# ...

# %%
(data['Area_sqft'].astype(float).isnull().sum() / len(data['Area_sqft'])) * 100
# Out:
# np.float64(0.5110514884374601)

# %%
sns.histplot(data['Area_sqft'],kde=True,bins=100)   # kernel density estimation
# Out:
# <Axes: xlabel='Area_sqft', ylabel='Count'>

# %%
sns.histplot(data['Area_sqft'].dropna(),kde=True,bins=100)
# Out:
# <Axes: xlabel='Area_sqft', ylabel='Count'>

# %%
data['Area_sqft']=data['Area_sqft'].fillna(data['Area_sqft'].median().astype(float))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1418355187.py in <cell line: 0>()
# ----> 1 data['Area_sqft']=data['Area_sqft'].fillna(data['Area_sqft'].median().astype(float))
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in median(self, axis, skipna, numeric_only, **kwargs)
#    6557         **kwargs,
#    6558     ):
# -> 6559         return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#    6560
#    6561     @doc(make_doc("sem", ndim=1))
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in median(self, axis, skipna, numeric_only, **kwargs)
#   12429         **kwargs,
#   12430     ) -> Series | float:
# > 12431         return self._stat_function(
#   12432             "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12433         )
#
# ...

# %%
data
# Out:
#       HOUSEID Date_Sold          City Area_sqft Bedrooms  Bathrooms Garage  \
# 0       H5239       NaT  Bhubaneshwar      1503        1          4    Yes
# 1       H2788       NaT  Bhubaneshwar       918        3          1     No
# 2       H5208       NaT  Bhubaneshwar      1358      Two          2      N
# 3       H1742       NaT       Cuttack      1085    Three          4      N
# 4       H4533       NaT   Bhubaneswar      3292        1          3     No
# ...       ...       ...           ...       ...      ...        ...    ...
# 15649   H2162       NaT          Puri      2004      Two          3    Yes
# 15650   H4306       NaT  Bhubaneshwar      2950        4          4     No
# 15651   H4935       NaT          Puri      2377        2          1    YES
# 15652   H1478       NaT          BBSR       980        1          3      Y
# 15653   H0928       NaT       Khordha      2456        2          1    YES
#
# ...

# %%
data['Bedrooms'].unique()
# Out:
# array(['1', '3', 'Two', 'Three', '2', '4'], dtype=object)

# %%
data['Bedrooms']=data['Bedrooms'].replace('Two',2)
data['Bedrooms']=data['Bedrooms'].replace('Three',3)

# %%
data['Bedrooms']=data['Bedrooms'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15654 entries, 0 to 15653
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   HOUSEID             15654 non-null  object
#  1   Date_Sold           0 non-null      datetime64[ns]
#  2   City                15654 non-null  object
#  3   Area_sqft           15574 non-null  object
#  4   Bedrooms            15654 non-null  int64
#  5   Bathrooms           15654 non-null  int64
#  6   Garage              15654 non-null  object
#  7   Year_Built          15654 non-null  int64
#  8   Price               15578 non-null  object
#  9   OwnerName           15654 non-null  object
#  10  Contact             15654 non-null  object
#  11  Email               15654 non-null  object
#  12  Property_Type       15654 non-null  object
#  13  Furnished           15654 non-null  object
#  14  Floor_No            15654 non-null  object
# ...

# %%
data['Bedrooms'].unique()
# Out:
# array([1, 3, 2, 4])

# %%
data['City']=data['City'].replace(['Bhubaneshwar','BBSR'],['Bhubaneswar','Bhubaneswar'])

# %%
data['City'].unique()
# Out:
# array(['Bhubaneswar', 'Cuttack', 'Puri', 'Khordha'], dtype=object)

# %%
data.head()
# Out:
#   HOUSEID Date_Sold         City Area_sqft  Bedrooms  Bathrooms Garage  \
# 0   H5239       NaT  Bhubaneswar      1503         1          4    Yes
# 1   H2788       NaT  Bhubaneswar       918         3          1     No
# 2   H5208       NaT  Bhubaneswar      1358         2          2      N
# 3   H1742       NaT      Cuttack      1085         3          4      N
# 4   H4533       NaT  Bhubaneswar      3292         1          3     No
#
#    Year_Built    Price OwnerName  ... Floor_No Total_Floors Latitude  \
# 0        1981     5.7M     Pooja  ...   Ground            5  20.3094
# 1        2014  8350753    Rakesh  ...        2            2  20.3553
# 2        1995     9.8M     Meena  ...        3            5  19.5662
# 3        2028  5679591      Arun  ...   Ground            2  19.8848
# 4        2028  2054447    Rajesh  ...        1            6  20.2625
#
#   Longitude Loan_Status  Registration_Price             Notes  Day Month  Year
# ...

# %%
data['Property_Type'].unique()
# Out:
# array(['Flat', 'Apartment', 'APT', 'House', 'Villa'], dtype=object)

# %%
data['Property_Type']= data['Property_Type'].replace(['APT','Flat'],['Apartment','Apartment'])

# %%
data['Floor_No'].unique()
# Out:
# array(['Ground', '2', '3', '1', 'G', '0'], dtype=object)

# %%
data['Floor_No']=data['Floor_No'].replace(['Ground','G'],[0,0])

# %%
data
# Out:
#       HOUSEID Date_Sold         City Area_sqft  Bedrooms  Bathrooms Garage  \
# 0       H5239       NaT  Bhubaneswar      1503         1          4    Yes
# 1       H2788       NaT  Bhubaneswar       918         3          1     No
# 2       H5208       NaT  Bhubaneswar      1358         2          2      N
# 3       H1742       NaT      Cuttack      1085         3          4      N
# 4       H4533       NaT  Bhubaneswar      3292         1          3     No
# ...       ...       ...          ...       ...       ...        ...    ...
# 15649   H2162       NaT         Puri      2004         2          3    Yes
# 15650   H4306       NaT  Bhubaneswar      2950         4          4     No
# 15651   H4935       NaT         Puri      2377         2          1    YES
# 15652   H1478       NaT  Bhubaneswar       980         1          3      Y
# 15653   H0928       NaT      Khordha      2456         2          1    YES
#
# ...

# %%
data['Floor_No']=data['Floor_No'].astype(int)

# %%
data['Floor_No'].unique()
# Out:
# array([0, 2, 3, 1])

# %%
data.head()
# Out:
#   HOUSEID Date_Sold         City Area_sqft  Bedrooms  Bathrooms Garage  \
# 0   H5239       NaT  Bhubaneswar      1503         1          4    Yes
# 1   H2788       NaT  Bhubaneswar       918         3          1     No
# 2   H5208       NaT  Bhubaneswar      1358         2          2      N
# 3   H1742       NaT      Cuttack      1085         3          4      N
# 4   H4533       NaT  Bhubaneswar      3292         1          3     No
#
#    Year_Built    Price OwnerName  ... Floor_No Total_Floors Latitude  \
# 0        1981     5.7M     Pooja  ...        0            5  20.3094
# 1        2014  8350753    Rakesh  ...        2            2  20.3553
# 2        1995     9.8M     Meena  ...        3            5  19.5662
# 3        2028  5679591      Arun  ...        0            2  19.8848
# 4        2028  2054447    Rajesh  ...        1            6  20.2625
#
#   Longitude  Loan_Status  Registration_Price             Notes  Day Month  \
# ...

# %%
data['Furnished']=data['Furnished'].replace(['Y','N'],['Yes','No'])

# %%
data['Furnished'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data.head()
# Out:
#   HOUSEID Date_Sold         City Area_sqft  Bedrooms  Bathrooms Garage  \
# 0   H5239       NaT  Bhubaneswar      1503         1          4    Yes
# 1   H2788       NaT  Bhubaneswar       918         3          1     No
# 2   H5208       NaT  Bhubaneswar      1358         2          2      N
# 3   H1742       NaT      Cuttack      1085         3          4      N
# 4   H4533       NaT  Bhubaneswar      3292         1          3     No
#
#    Year_Built    Price OwnerName  ... Floor_No Total_Floors Latitude  \
# 0        1981     5.7M     Pooja  ...        0            5  20.3094
# 1        2014  8350753    Rakesh  ...        2            2  20.3553
# 2        1995     9.8M     Meena  ...        3            5  19.5662
# 3        2028  5679591      Arun  ...        0            2  19.8848
# 4        2028  2054447    Rajesh  ...        1            6  20.2625
#
#   Longitude  Loan_Status  Registration_Price             Notes  Day Month  \
# ...

# %%
data['Garage']=data['Garage'].replace(['Y','YES','NO','N'],['Yes','Yes','No','No'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15654 entries, 0 to 15653
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   HOUSEID             15654 non-null  object
#  1   Date_Sold           0 non-null      datetime64[ns]
#  2   City                15654 non-null  object
#  3   Area_sqft           15574 non-null  object
#  4   Bedrooms            15654 non-null  int64
#  5   Bathrooms           15654 non-null  int64
#  6   Garage              15654 non-null  object
#  7   Year_Built          15654 non-null  int64
#  8   Price               15578 non-null  object
#  9   OwnerName           15654 non-null  object
#  10  Contact             15654 non-null  object
#  11  Email               15654 non-null  object
#  12  Property_Type       15654 non-null  object
#  13  Furnished           15654 non-null  object
#  14  Floor_No            15654 non-null  int64
# ...

# %%
def convert_price(x):
  if isinstance(x,str) and 'M' in x:
    return float(x.replace('M',''))*1000000
  else:
    return float(x)

# %%
data['Price']
# Out:
# 0            5.7M
# 1         8350753
# 2            9.8M
# 3         5679591
# 4         2054447
#            ...
# 15649        9.1M
# 15650    12639088
# 15651     6806979
# 15652       14.4M
# 15653     6474127
# Name: Price, Length: 15654, dtype: object
