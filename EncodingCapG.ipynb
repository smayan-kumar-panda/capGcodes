# %% [markdown]
# <a href="https://colab.research.google.com/github/smayan-kumar-panda/capGcodes/blob/main/EncodingCapG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
import pandas as pd

# %%
df=pd.read_csv('iris_data.csv')
df
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
le = LabelEncoder()
df['Species'] = le.fit_transform(df['Species'])
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %%
df_onehot = pd.get_dummies(df, columns=['Species'])
df_onehot
# Out:
#       Id  SepalLengthCm  SepalWidthCm  ...  Species_0  Species_1  Species_2
# 0      1            5.1           3.5  ...       True      False      False
# 1      2            4.9           3.0  ...       True      False      False
# 2      3            4.7           3.2  ...       True      False      False
# 3      4            4.6           3.1  ...       True      False      False
# 4      5            5.0           3.6  ...       True      False      False
# ..   ...            ...           ...  ...        ...        ...        ...
# 145  146            6.7           3.0  ...      False      False       True
# 146  147            6.3           2.5  ...      False      False       True
# 147  148            6.5           3.0  ...      False      False       True
# 148  149            6.2           3.4  ...      False      False       True
# 149  150            5.9           3.0  ...      False      False       True
#
# [150 rows x 8 columns]

# %%
oe = OrdinalEncoder()
df['Species'] = oe.fit_transform(df[['Species']])
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2      0.0
# 1      2            4.9           3.0            1.4           0.2      0.0
# 2      3            4.7           3.2            1.3           0.2      0.0
# 3      4            4.6           3.1            1.5           0.2      0.0
# 4      5            5.0           3.6            1.4           0.2      0.0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3      2.0
# 146  147            6.3           2.5            5.0           1.9      2.0
# 147  148            6.5           3.0            5.2           2.0      2.0
# 148  149            6.2           3.4            5.4           2.3      2.0
# 149  150            5.9           3.0            5.1           1.8      2.0
#
# [150 rows x 6 columns]
